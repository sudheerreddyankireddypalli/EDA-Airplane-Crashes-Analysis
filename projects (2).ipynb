# %% [markdown]
# # PROJECT ON AIRPLANE CRASHES AND FATALITIES

# %% [markdown]
# ### DATA COLLECTION FROM : KAGGLE
# LINK:https://www.kaggle.com/datasets/thedevastator/airplane-crashes-and-fatalities

# %% [markdown]
# #### ABOUT DATASET:Airplane Crashes and Fatalities
# This dataset showcases Boeing  accidents that have occurred since 1908. The data includes information on the date, time, location, operator, flight number, route, type of aircraft, registration number, cn/In number of persons on board, fatalities, ground fatalities, and a summary of the accident.

# %% [markdown]
# ### How to use the dataset
# This dataset includes information on over 5,000 airplane crashes around the world.
#
# This is an absolutely essential dataset for anyone interested in aviation safety! Here you will find information on when and where each crash occurred, what type of plane was involved, how many people were killed, and much more.
#
# This dataset is perfect for anyone interested in data visualization or analysis. With so much information available, there are endless possibilities for interesting stories and insights that can be gleaned from this data.
#
# So whether you're a seasoned data pro or just getting started, this dataset is sure to give you plenty to work with. So get started today and see what you can discover!

# %% [markdown]
# ## Research Ideas
# 1.Plot a map of all flight routes.
#
# 2.Analyze what type of aircraft is involved in the most crashes.
#
# 3.Identify patterns in where/when crashes occur.

# %% [markdown]
# ### Columns
# index: the index of the row
#
# Date: the date of the incident
#
# Time: the time of the incident
#
# Location: the location of the incident
#
# Operator: the operator of the aircraft
#
# Flight #: the flight number of the aircraft
#
# Route: the route of the aircraft
#
# Type: the type of aircraft
#
# Registration: the registration of the aircraft
#
# cn/In: the construction number/serial number of the aircraft
#
# Aboard: the number of people on board the aircraft
#
# Fatalities: the number of fatalities in the incident
#
# Ground: the number of people on the ground killed in the incident
#
# Summary: a summary of the incident

# %% [markdown]
# ##  Acknowledgements
# This dataset was obtained from the Data Society. If you use this dataset in your research, please credit the Data Society.
#
# Columns: index, Date, Time, Location, Operator, Flight #, Route, Type, Registration, cn/In, Aboard, Fatalities Ground Summary

# %% [markdown]
# # DATA READING AND CLEANING

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv(r"C:\Users\sudhe\Downloads\Airplane_Crashes_and_Fatalities_Since_1908 (1).csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         5268 non-null   int64
#  1   Date          5268 non-null   object
#  2   Time          3049 non-null   object
#  3   Location      5248 non-null   object
#  4   Operator      5250 non-null   object
#  5   Flight #      1069 non-null   object
#  6   Route         3561 non-null   object
#  7   Type          5241 non-null   object
#  8   Registration  4933 non-null   object
#  9   cn/In         4040 non-null   object
#  10  Aboard        5246 non-null   float64
#  11  Fatalities    5256 non-null   float64
#  12  Ground        5246 non-null   float64
#  13  Summary       4878 non-null   object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 576.3+ KB

# %% [markdown]
# ## Data Understanding

# %%
df.head()
# Out:
#    index        Date   Time                            Location  \
# 0      0  09/17/1908  17:18                 Fort Myer, Virginia
# 1      1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2      2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3      3  09/09/1913  18:30                  Over the North Sea
# 4      4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# ...

# %% [markdown]
# # Basic Statistics & Data Shape

# %%
df.shape           # rows & columns
df.describe()      # mean, std, min, max for numerical columns
df.duplicated().sum()  # check for duplicate rows
# Out:
# np.int64(0)

# %%
df['Survival_Rate'] = (df['Aboard'] - df['Fatalities']) / df['Aboard'] * 100
df['Fatality_Rate'] = df['Fatalities'] / df['Aboard'] * 100
sns.histplot(df['Fatality_Rate'], bins=30, kde=True)

# %% [markdown]
# # Data Cleaning

# %%
df = df.rename(columns={
    "Flight #": "Flight_no",
    "another_column": "renamed_column"
})

# %%
df
# Out:
#       index        Date   Time  \
# 0         0  09/17/1908  17:18
# 1         1  07/12/1912  06:30
# 2         2  08/06/1913    NaN
# 3         3  09/09/1913  18:30
# 4         4  10/17/1913  10:30
# ...     ...         ...    ...
# 5263   5263  05/20/2009  06:30
# 5264   5264  05/26/2009    NaN
# 5265   5265  06/01/2009  00:15
# 5266   5266  06/07/2009  08:30
# 5267   5267  06/08/2009    NaN
#
#                                                Location  \
# 0                                   Fort Myer, Virginia
# 1                               AtlantiCity, New Jersey
# 2                    Victoria, British Columbia, Canada
# 3                                    Over the North Sea
# 4                            Near Johannisthal, Germany
# ...                                                 ...
# 5263                             Near Madiun, Indonesia
# 5264                  Near Isiro, DemocratiRepubliCongo
# 5265  AtlantiOcean, 570 miles northeast of Natal, Br...
# ...

# %%
df.isnull()
# Out:
#       index   Date   Time  Location  Operator  Flight_no  Route   Type  \
# 0     False  False  False     False     False       True  False  False
# 1     False  False  False     False     False       True  False  False
# 2     False  False   True     False     False      False   True  False
# 3     False  False  False     False     False       True   True  False
# 4     False  False  False     False     False       True   True  False
# ...     ...    ...    ...       ...       ...        ...    ...    ...
# 5263  False  False  False     False     False       True  False  False
# 5264  False  False   True     False     False       True  False  False
# 5265  False  False  False     False     False      False  False  False
# 5266  False  False  False     False     False       True  False  False
# 5267  False  False   True     False     False       True  False  False
#
#       Registration  cn/In  Aboard  Fatalities  Ground  Summary
# ...

# %%
df["Flight_no"].isnull().sum()
#df.head()
# Out:
# np.int64(4199)

# %%
df["Flight_no"].fillna("unknown",inplace=True)

# %% [markdown]
# # Correlation Heatmap (missing entirely)

# %%
sns.heatmap(df[['Aboard', 'Fatalities', 'Ground']].corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## numirical data

# %%
num_df=df.select_dtypes(include="number")
    
num_df.head()
# Out:
#    index  Aboard  Fatalities  Ground
# 0      0     2.0         1.0     0.0
# 1      1     5.0         5.0     0.0
# 2      2     1.0         1.0     0.0
# 3      3    20.0        14.0     0.0
# 4      4    30.0        30.0     0.0

# %%
num_df.isnull().sum()
# Out:
# index          0
# Aboard        22
# Fatalities    12
# Ground        22
# dtype: int64

# %%
df["Aboard"].fillna(df["Aboard"].median(),inplace=True)

# %%
df["Fatalities"].fillna(df["Fatalities"].median(),inplace=True)

# %%
df["Ground"].fillna(df["Ground"].median(),inplace=True)

# %%
num_df.isnull().sum()
# Out:
# index          0
# Aboard        22
# Fatalities    12
# Ground        22
# dtype: int64

# %% [markdown]
# ## catgorical data

# %%
cat_df=df.select_dtypes(include="object")
cat_df.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight_no          Route                    Type  \
# 0    Military - U.S. Army   unknown  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy   unknown    Test flight               Dirigible
# 2                 Private         -            NaN        Curtiss seaplane
# 3  Military - German Navy   unknown            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy   unknown            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In                                            Summary
# 0          NaN     1  During a demonstration flight, a U.S. Army fly...
# ...

# %%
cat_df.isnull().sum()
# Out:
# Date               0
# Time            2219
# Location          20
# Operator          18
# Flight_no          0
# Route           1707
# Type              27
# Registration     335
# cn/In           1228
# Summary          390
# dtype: int64

# %%
emp1=[]
count=0
for i in cat_df.columns:
    for i in cat_df[i]:
        emp1.append(i)

# %%
emp1
# Out:
# ['09/17/1908',
#  '07/12/1912',
#  '08/06/1913',
#  '09/09/1913',
#  '10/17/1913',
#  '03/05/1915',
#  '09/03/1915',
#  '07/28/1916',
#  '09/24/1916',
#  '10/01/1916',
#  '11/21/1916',
#  '11/28/1916',
#  '03/04/1917',
#  '03/30/1917',
#  '05/14/1917',
#  '06/14/1917',
#  '08/21/1917',
#  '10/20/1917',
#  '04/07/1918',
#  '05/10/1918',
#  '08/11/1918',
#  '12/16/1918',
#  '05/25/1919',
#  '07/19/1919',
#  '10/02/1919',
#  '10/14/1919',
#  '10/20/1919',
#  '10/30/1919',
#  '03/10/1920',
#  '03/30/1920',
#  '04/10/1920',
#  '04/11/1920',
#  '05/12/1920',
#  '06/06/1920',
#  '08/16/1920',
#  '08/16/1920',
#  '09/01/1920',
#  '09/15/1920',
#  '09/27/1920',
#  '10/02/1920',
#  '10/05/1920',
#  '10/15/1920',
#  '11/07/1920',
#  '12/14/1920',
#  '12/24/1920',
#  '02/03/1921',
#  '02/09/1921',
#  '02/15/1921',
#  '02/22/1921',
#  '04/06/1921',
#  '04/21/1921',
#  '04/29/1921',
#  '05/17/1921',
#  '07/16/1921',
#  '08/14/1921',
#  '08/24/1921',
#  '09/06/1921',
#  '12/05/1921',
# ...

# %%
" " in emp1
# Out:
# False

# %%
"" in emp1
# Out:
# False

# %%
cat_df.isnull().sum()
# Out:
# Date               0
# Time            2219
# Location          20
# Operator          18
# Flight_no          0
# Route           1707
# Type              27
# Registration     335
# cn/In           1228
# Summary          390
# dtype: int64

# %%
a= cat_df.columns
a
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight_no', 'Route', 'Type',
#        'Registration', 'cn/In', 'Summary'],
#       dtype='object')

# %%
for col in cat_df.columns:
    if col not in ["Date", "Time"]:
        cat_df[col].fillna("unknown", inplace=True)

# %%
# Loop through categorical columns
for col in cat_df.columns:
    # Skip Date and Time columns
    if col in ["Date", "Time"]:
        continue
    # Fill NaN values in this column with "unknown"
    cat_df[col] = cat_df[col].fillna("unknown")

# %%
for col in cat_df.columns:
    if col not in ["Date", "Time"]:
        cat_df[col].fillna("unknown", inplace=True)

# %%
cat_df.isnull().sum()
# Out:
# Date               0
# Time            2219
# Location           0
# Operator           0
# Flight_no          0
# Route              0
# Type               0
# Registration       0
# cn/In              0
# Summary            0
# dtype: int64

# %%
df["Flight_no"].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Time'].max
# Out:
# <bound method Series.max of 0       17:18
# 1       06:30
# 2         NaN
# 3       18:30
# 4       10:30
#         ...
# 5263    06:30
# 5264      NaN
# 5265    00:15
# 5266    08:30
# 5267      NaN
# Name: Time, Length: 5268, dtype: object>

# %%
df['Time'].fillna('6:30').sum()
# Out:
# "17:1806:306:3018:3010:3001:0015:206:3001:0023:456:3023:456:306:3005:1508:4507:0007:4521:306:3010:006:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:3017:406:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:3002:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:3005:306:306:306:306:306:306:306:306:306:306:306:3013:156:306:306:306:306:306:306:306:306:306:3008:306:306:306:3010:006:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:306:3010:0008:006:306:306:306:306:306:306:306:306:306:306:3009:186:306:306:306:306:306:306:306:306:306:306:306:306:306:30c: 1:006:306:306:306:306:306:306:3007:006:306:306:306:306:306:306:306:306:3018:236:3017:306:306:30c:17:006:306:306:306:306:306:306:3002:0509:456:306:306:306:306:30c: 2:006:306:306:306:306:306:306:3010:456:3023:306
# ...

# %%
df['Time'].isnull().sum()
# Out:
# np.int64(2219)

# %%
df['Date'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y', errors='coerce')

# Display the first few rows to confirm the conversion
df['Date'].head()
# Out:
# 0   1908-09-17
# 1   1912-07-12
# 2   1913-08-06
# 3   1913-09-09
# 4   1913-10-17
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# # Feature Engineering¶

# %%
# Handle missing values by filling or dropping as necessary

# Drop rows where 'Date' is missing, as it's crucial for analysis
df = df.dropna(subset=['Date'])

# Optionally fill missing 'Time' values with a placeholder or drop if necessary
df['Time'] = df['Time'].fillna('Unknown')

# For columns like 'Flight #', 'Route', 'Registration', fill missing values with 'Unknown'
df["Flight_no"] = df['Flight_no'].fillna('Unknown')
df['Route'] = df['Route'].fillna('Unknown')
df['Registration'] = df['Registration'].fillna('Unknown')

# Drop rows where 'Aboard', 'Fatalities', or 'Ground' are missing, as these are crucial for analysis
df = df.dropna(subset=['Aboard', 'Fatalities', 'Ground'])

# Check for any remaining missing values
df.isnull().sum()
# Out:
# index              0
# Date               0
# Time               0
# Location          20
# Operator          18
# Flight_no          0
# Route              0
# Type              27
# Registration       0
# cn/In           1228
# Aboard             0
# Fatalities         0
# Ground             0
# Summary          390
# dtype: int64

# %%
# Extract year and month from 'Date' for further analysis
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# Display the first few rows to confirm the new features
df[['Date', 'Year', 'Month']].head()
# Out:
#         Date  Year  Month
# 0 1908-09-17  1908      9
# 1 1912-07-12  1912      7
# 2 1913-08-06  1913      8
# 3 1913-09-09  1913      9
# 4 1913-10-17  1913     10

# %%
# Visualization 1: Number of crashes per year
plt.figure(figsize=(12, 6))
sns.histplot(df['Year'], bins=80, kde=False, color='blue')
plt.title('Number of Airplane Crashes per Year')
plt.xlabel('Year')
plt.ylabel('Number of Crashes')
plt.show()

# %%
# Visualization 2: Number of crashes per month
plt.figure(figsize=(12, 6))
sns.countplot(x='Month', data=df, palette='viridis')
plt.title('Number of Airplane Crashes per Month')
plt.xlabel('Month')
plt.ylabel('Number of Crashes')
plt.show()

# %%
# Visualization 3: Top 10 operators involved in crashes
plt.figure(figsize=(12, 8)) 
top_operators = df['Operator'].value_counts().nlargest(10)
sns.barplot(x=top_operators.values, y=top_operators.index, palette='magma')
plt.title('Top 10 Operators Involved in Crashes')
plt.xlabel('Number of Crashes')
plt.ylabel('Operator')
plt.show()

# %%
# Visualization 6: Top 10 types of aircraft involved in crashes
plt.figure(figsize=(12, 8))
top_types = df['Type'].value_counts().nlargest(10)
sns.barplot(x=top_types.values, y=top_types.index, palette='coolwarm')
plt.title('Top 10 Types of Aircraft Involved in Crashes')
plt.xlabel('Number of Crashes')
plt.ylabel('Type of Aircraft')
plt.show()

# %%
# Ensure we are only summing numeric columns
df_grouped_year = df.groupby('Year').sum(numeric_only=True)

# Plot the time series of total fatalities over time
plt.figure(figsize=(14, 6))
plt.plot(df_grouped_year.index, df_grouped_year['Fatalities'], marker='o', color='darkred')
plt.title('Total Fatalities in Airplane Crashes Over Time')
plt.xlabel('Year')
plt.ylabel('Total Fatalities')
plt.grid(True)
plt.show()

# %%
# Visualization 8: Top 10 locations with the most crashes
plt.figure(figsize=(12, 8))
top_locations = df['Location'].value_counts().nlargest(10)
sns.barplot(x=top_locations.values, y=top_locations.index, palette='copper')
plt.title('Top 10 Locations with the Most Crashes')
plt.xlabel('Number of Crashes')
plt.ylabel('Location')
plt.show()

# %%
# Visualization 9: Number of crashes by route (Top 10)
plt.figure(figsize=(12, 8))
top_routes = df['Route'].value_counts().nlargest(10)
sns.barplot(x=top_routes.values, y=top_routes.index, palette='rocket')
plt.title('Top 10 Routes with the Most Crashes')
plt.xlabel('Number of Crashes')
plt.ylabel('Route')
plt.show()

# %%
plt.figure(figsize=(10, 8))

# Get top 10 crash locations
top_locations = df['Location'].value_counts().nlargest(10)

# Create pie chart
plt.pie(
    top_locations.values, 
    labels=top_locations.index, 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=sns.color_palette('copper', 10)
)

plt.title('Top 10 Locations with the Most Crashes')
plt.axis('equal')  # Ensures pie is a circle
plt.show()

# %%
df['cn/In'].fillna('ABC')
# Out:
# 0          1
# 1        ABC
# 2        ABC
# 3        ABC
# 4        ABC
#         ...
# 5263    1982
# 5264    5005
# 5265     660
# 5266     424
# 5267     ABC
# Name: cn/In, Length: 5268, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         5268 non-null   int64
#  1   Date          5268 non-null   datetime64[ns]
#  2   Time          5268 non-null   object
#  3   Location      5248 non-null   object
#  4   Operator      5250 non-null   object
#  5   Flight_no     5268 non-null   object
#  6   Route         5268 non-null   object
#  7   Type          5241 non-null   object
#  8   Registration  5268 non-null   object
#  9   cn/In         4040 non-null   object
#  10  Aboard        5268 non-null   float64
#  11  Fatalities    5268 non-null   float64
#  12  Ground        5268 non-null   float64
#  13  Summary       4878 non-null   object
#  14  Year          5268 non-null   int32
#  15  Month         5268 non-null   int32
# dtypes: datetime64[ns](1), float64(3), int32(2), int64(1), object(9)
# ...

# %%
df.isnull()
# Out:
#       index   Date   Time  Location  Operator  Flight_no  Route   Type  \
# 0     False  False  False     False     False      False  False  False
# 1     False  False  False     False     False      False  False  False
# 2     False  False  False     False     False      False  False  False
# 3     False  False  False     False     False      False  False  False
# 4     False  False  False     False     False      False  False  False
# ...     ...    ...    ...       ...       ...        ...    ...    ...
# 5263  False  False  False     False     False      False  False  False
# 5264  False  False  False     False     False      False  False  False
# 5265  False  False  False     False     False      False  False  False
# 5266  False  False  False     False     False      False  False  False
# 5267  False  False  False     False     False      False  False  False
#
#       Registration  cn/In  Aboard  Fatalities  Ground  Summary   Year  Month
# ...

# %% [markdown]
# #  Survival Rate Analysis

# %%
df['Survival_Rate'] = (df['Aboard'] - df['Fatalities']) / df['Aboard'] * 100
df['Fatality_Rate'] = df['Fatalities'] / df['Aboard'] * 100
sns.histplot(df['Fatality_Rate'], bins=30, kde=True)
# Out:
# <Axes: xlabel='Fatality_Rate', ylabel='Count'>

# %% [markdown]
# # Military vs. Civil Operator Split

# %%
df['Operator_Type'] = df['Operator'].apply(lambda x: 'Military' if 'Military' in str(x) or 'Air Force' in str(x) else 'Civil')
df['Operator_Type'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Deadliest Crashes (Top 10 rows by Fatalities)

# %%
df.nlargest(10, 'Fatalities')[['Date', 'Operator', 'Type', 'Location', 'Aboard', 'Fatalities']]
# Out:
#            Date                                    Operator  \
# 2963 1977-03-27            Pan American World Airways / KLM
# 3568 1985-08-12                             Japan Air Lines
# 4455 1996-11-12  Saudi Arabian Airlines / Kazastan Airlines
# 2726 1974-03-03                      Turkish Airlines (THY)
# 3562 1985-06-23                                   Air India
# 3240 1980-08-19                      Saudi Arabian Airlines
# 3775 1988-07-03                                    Iran Air
# 4916 2003-02-19  Military - IslamiRevolution's Guards Corps
# 3137 1979-05-25                           American Airlines
# 3436 1983-09-01                             Korean Airlines
#
#                                       Type  \
# 2963  Boeing B-747-121 / Boeing B-747-206B
# 3568                     Boeing B-747-SR46
# 4455  Boeing B-747-168B / Ilyushin IL-76TD
# 2726            McDonnell Douglas DC-10-10
# 3562                     Boeing B-747-237B
# ...

# %% [markdown]
# # Conclusions / Insights Cell
# This exploratory data analysis examined over 5,000 airplane crashes recorded since 1908, uncovering temporal trends, high-risk operators and aircraft types, and patterns in fatalities. The dataset reveals how aviation safety has evolved over a century — with crashes peaking mid-20th century and declining significantly in recent decades due to improved technology and regulation.

# %% [markdown]
# ### Key Findings:
# 1. **Crash frequency peaked in the 1940s–1970s** and has significantly declined since the 1980s due to better safety regulations and aircraft technology.
# 2. **Military operators** (Air Force, Army) dominate the top crash counts, reflecting the high-risk nature of wartime and military flight operations.
# 3. **Douglas DC-3** is the most frequently crashed aircraft — mainly due to its widespread use across several decades, not inherent danger.
# 4. **Fatalities are positively correlated with the number of people aboard**, but survival outcomes vary greatly depending on crash type and emergency response.
# 5. **Fatality distribution is heavily right-skewed** — most crashes are small-scale, but rare catastrophic events significantly inflate overall statistics.
# 6. **Total fatalities peaked in the 1970s** and have been declining, aligning with introduction of modern aviation safety standards globally.

# %% [markdown]
# ### Limitations:
# - Crash counts are not normalized by flight hours, so comparisons across eras or operators may be misleading.
# - Significant missing data in `Time`, `Route`, and `cn/In` columns.
# - The `Summary` column contains rich unstructured information about causes that was not analyzed
